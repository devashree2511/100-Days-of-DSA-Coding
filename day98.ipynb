# %% [markdown]
# <a href="https://colab.research.google.com/github/devashree2511/100-Days-of-DSA-Coding/blob/main/day98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile day98.c
# #include <stdio.h>
# #include <stdlib.h>
#
# typedef struct {
#     int start, end;
# } Interval;
#
# int compare(const void *a, const void *b) {
#     Interval *i1 = (Interval *)a;
#     Interval *i2 = (Interval *)b;
#     return i1->start - i2->start;
# }
#
# int main() {
#     int n;
#     scanf("%d", &n);
#
#     Interval arr[n];
#     for (int i = 0; i < n; i++) {
#         scanf("%d %d", &arr[i].start, &arr[i].end);
#     }
#
#     qsort(arr, n, sizeof(Interval), compare);
#
#     Interval result[n];
#     int index = 0;
#
#     result[0] = arr[0];
#
#     for (int i = 1; i < n; i++) {
#         if (arr[i].start <= result[index].end) {
#             if (arr[i].end > result[index].end)
#                 result[index].end = arr[i].end;
#         } else {
#             index++;
#             result[index] = arr[i];
#         }
#     }
#
#     for (int i = 0; i <= index; i++) {
#         printf("%d %d\n", result[i].start, result[i].end);
#     }
#
#     return 0;
# }
# Out:
# Writing day98.c

# %%
# !gcc day98.c
# !./a.out
# Out:
# 4 1 3 2 6 8 10 15 18
# 1 6
# 8 10
# 15 18
