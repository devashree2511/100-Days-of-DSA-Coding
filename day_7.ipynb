# %% [markdown]
# <a href="https://colab.research.google.com/github/devashree2511/100-Days-of-DSA-Coding/blob/main/day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile fib.c
# #include <stdio.h>
#
# int fib(int n) {
#     if (n == 0) return 0;
#     if (n == 1) return 1;
#     return fib(n - 1) + fib(n - 2);
# }
#
# int main() {
#     int n;
#     scanf("%d", &n);
#     printf("%d\n", fib(n));
#     return 0;
# }
# Out:
# Writing fib.c

# %%
# !gcc fib.c
# !./a.out
# Out:
# 40
# 102334155
