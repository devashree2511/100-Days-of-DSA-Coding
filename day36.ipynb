# %% [markdown]
# <a href="https://colab.research.google.com/github/devashree2511/100-Days-of-DSA-Coding/blob/main/day36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile day36.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct Node {
#     int data;
#     struct Node* next;
# };
#
# struct Node *front = NULL, *rear = NULL;
#
# // Enqueue
# void enqueue(int x) {
#     struct Node* temp = (struct Node*)malloc(sizeof(struct Node));
#     temp->data = x;
#
#     if (rear == NULL) {
#         front = rear = temp;
#         rear->next = front;
#         return;
#     }
#
#     rear->next = temp;
#     rear = temp;
#     rear->next = front;
# }
#
# // Dequeue
# void dequeue() {
#     if (front == NULL)
#         return;
#
#     if (front == rear) {
#         free(front);
#         front = rear = NULL;
#         return;
#     }
#
#     struct Node* temp = front;
#     front = front->next;
#     rear->next = front;
#     free(temp);
# }
#
# // Display
# void display() {
#     if (front == NULL)
#         return;
#
#     struct Node* temp = front;
#     do {
#         printf("%d ", temp->data);
#         temp = temp->next;
#     } while (temp != front);
# }
#
# int main() {
#     int n, m, x;
#
#     scanf("%d", &n);
#
#     for (int i = 0; i < n; i++) {
#         scanf("%d", &x);
#         enqueue(x);
#     }
#
#     scanf("%d", &m);
#
#     for (int i = 0; i < m; i++) {
#         dequeue();
#     }
#
#     display();
#
#     return 0;
# }
# Out:
# Writing day36.c

# %%
# !gcc day36.c
# !./a.out
# Out:
# 5 10 20 30 40 50 2
# 30 40 50
