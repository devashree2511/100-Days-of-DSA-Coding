# %% [markdown]
# <a href="https://colab.research.google.com/github/devashree2511/100-Days-of-DSA-Coding/blob/main/day55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile day56.c
# #include <stdio.h>
# #include <stdlib.h>
#
# struct TreeNode {
#     int val;
#     struct TreeNode* left;
#     struct TreeNode* right;
# };
#
#
# struct TreeNode* createNode(int val) {
#     struct TreeNode* node = (struct TreeNode*)malloc(sizeof(struct TreeNode));
#     node->val = val;
#     node->left = NULL;
#     node->right = NULL;
#     return node;
# }
#
#
# struct TreeNode* buildTree(int arr[], int n) {
#     if (n == 0 || arr[0] == -1) return NULL;
#
#     struct TreeNode* root = createNode(arr[0]);
#
#     struct TreeNode** queue = (struct TreeNode**)malloc(n * sizeof(struct TreeNode*));
#     int front = 0, rear = 0;
#
#     queue[rear++] = root;
#     int i = 1;
#
#     while (front < rear && i < n) {
#         struct TreeNode* current = queue[front++];
#
#
#         if (i < n && arr[i] != -1) {
#             current->left = createNode(arr[i]);
#             queue[rear++] = current->left;
#         }
#         i++;
#
#         if (i < n && arr[i] != -1) {
#             current->right = createNode(arr[i]);
#             queue[rear++] = current->right;
#         }
#         i++;
#     }
#
#     free(queue);
#     return root;
# }
#
#
# int isMirror(struct TreeNode* t1, struct TreeNode* t2) {
#     if (t1 == NULL && t2 == NULL) return 1;
#     if (t1 == NULL || t2 == NULL) return 0;
#
#     return (t1->val == t2->val &&
#             isMirror(t1->left, t2->right) &&
#             isMirror(t1->right, t2->left));
# }
#
#
# int isSymmetric(struct TreeNode* root) {
#     return isMirror(root, root);
# }
#
# int main() {
#     int n;
#     scanf("%d", &n);
#
#     int arr[n];
#     for (int i = 0; i < n; i++) {
#         scanf("%d", &arr[i]);
#     }
#
#     struct TreeNode* root = buildTree(arr, n);
#
#     if (isSymmetric(root))
#         printf("YES\n");
#     else
#         printf("NO\n");
#
#     return 0;
# }
# Out:
# Overwriting day56.c

# %%
# !gcc day56.c
# !./a.out
# Out:
# 7 1 2 2 3 4 4 3
# YES
