# %% [markdown]
# <a href="https://colab.research.google.com/github/devashree2511/100-Days-of-DSA-Coding/blob/main/day%2013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile matrix.c
# #include <stdio.h>
#
# int main() {
#     int r, c;
#     scanf("%d %d", &r, &c);
#
#     int matrix[r][c];
#
#     for (int i = 0; i < r; i++) {
#         for (int j = 0; j < c; j++) {
#             scanf("%d", &matrix[i][j]);
#         }
#     }
#
#     int top = 0, bottom = r - 1;
#     int left = 0, right = c - 1;
#
#     while (top <= bottom && left <= right) {
#
#         for (int i = left; i <= right; i++)
#             printf("%d ", matrix[top][i]);
#         top++;
#
#         for (int i = top; i <= bottom; i++)
#             printf("%d ", matrix[i][right]);
#         right--;
#
#         if (top <= bottom) {
#             for (int i = right; i >= left; i--)
#                 printf("%d ", matrix[bottom][i]);
#             bottom--;
#         }
#         if (left <= right) {
#             for (int i = bottom; i >= top; i--)
#                 printf("%d ", matrix[i][left]);
#             left++;
#         }
#     }
#
#     return 0;
# }
# Out:
# Writing matrix.c

# %%
# !gcc matrix.c
# !./a.out
# Out:
# 3 3 1 2 3 4 5 6 7 8 9
# 1 2 3 6 9 8 7 4 5
